# %%
import pandas as pd
import matplotlib
import scipy

# %%
df = pd.read_csv("data_b2_p3.csv", index_col=0)
df
# Out:
#       Млн. руб.
# Годы
# 1         15317
# 2         22620
# 3         37593
# 4         42245
# 5         50789

# %%
df.plot(kind='line')
# Out:
# <Axes: xlabel='Годы'>

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='Годы'>

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(kind='area')
# Out:
# <Axes: xlabel='Годы'>

# %%
df.plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>
